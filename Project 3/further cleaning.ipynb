# %%
import pandas as pd
import seaborn as sns

# %%
# read in all our data
traineddata = pd.read_csv("Bondora_raw.csv")
# Out:
# C:\Users\ajarir\AppData\Local\Temp\ipykernel_17892\3023559420.py:2: DtypeWarning: Columns (34,37,38,80,82,83,89,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   traineddata = pd.read_csv("Bondora_raw.csv")

# %%
mydata = pd.read_csv("Bondora_raw.csv")

# %%
forreal = mydata = pd.read_csv("modiefed_data.csv")

# %%
traineddata.EmploymentStatus.unique()
# Out:
# array([ 3., nan,  2.,  4.,  5.,  6.,  0., -1.])

# %%
sns.countplot(traineddata.EmploymentStatus)
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='count'>

# %%
forreal = forreal[forreal['EmploymentStatus'] != -1]

# %%
forreal = forreal[forreal['EmploymentStatus'] != 0]

# %%
sns.countplot(mydata.EmploymentStatus)
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='count'>

# %%
# Define loan categories
Unemployed = [1.0, 6.0]
employed = [2, 3]
Selfemployed = [5, 4]

# Replace loan categories in 'UseOfLoan' column
forreal['EmploymentStatus'] = forreal['EmploymentStatus'].replace({i: 'Unemployed' for i in Unemployed})\
                           .replace({i: 'employed' for i in employed})\
                           .replace({i: 'Selfemployed' for i in Selfemployed})\
                           .replace({7: 'Other'})

# %%
sns.countplot(forreal.EmploymentStatus)
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='count'>

# %%
forreal = forreal[forreal['EmploymentStatus'] != 0]

# %%
forreal['EmploymentStatus'].unique()
# Out:
# array(['employed', 'Selfemployed', 'Unemployed'], dtype=object)

# %%
sns.countplot(forreal.EmploymentStatus)
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='count'>

# %%
encoder = preprocessing.LabelEncoder()


forreal['EmploymentStatus'] = encoder.fit_transform(forreal['EmploymentStatus'] )

# %%
from mlxtend.preprocessing import minmax_scaling

# %%
from sklearn import preprocessing

# %% [markdown]
# # Save

# %%
forreal.to_csv('modiefeddata.csv', index=False)

# %%
forreal['Status']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 27853    2
# 27854    2
# 27855    1
# 27856    2
# 27857    1
# Name: Status, Length: 27835, dtype: int64
